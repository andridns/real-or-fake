# %%
import re
import os

# %%
f = open('kaskus_tematik_prep.txt', encoding='utf-8').read()

# %%
s = f[:100000]

# %%
print(s)
# Out:
# co.id/show_post/5...56d/1242/fr-fr
# FR COMBO 188 dan 93
# https://www.kaskus.co.id/show_post/5...98b4574/2674/-
# FR COMBO 26 dan 87
# https://www.kaskus.co.id/show_post/5...58b456d/3605/-
# FR COMBO 106 dan 18
# https://www.kaskus.co.id/show_post/5...fr-terapis-abg
# FR COMBO 106 dan 37
# https://www.kaskus.co.id/show_post/5...08b456f/3779/-
# FR COMBO 17 dan 26
# https://www.kaskus.co.id/show_post/5...88b456e/4372/-
# FR COMBO 31 dan 81
# https://www.kaskus.co.id/show_post/5...a8b4568/4735/-
# FR COMBO 65 dan 67
# https://www.kaskus.co.id/show_post/5.../fr-maret-2017
# FR COMBO 17 dan 27
# https://www.kaskus.co.id/show_post/5...b8b456c/5011/-
# FR COMBO 26 dan 63
# https://www.kaskus.co.id/show_post/5...48b456a/5207/-
#
#
# KUMPULAN FR FREELANCE
#
# FR FL 800 Michell*
# https://www.kaskus.co.id/show_post/5...28b4569/1466/-
# FR FL 801 Chi**
# https://www.kaskus.co.id/show_post/5...68b456d/4715/-
# FR FL 802 Jessic*
# https://www.kaskus.co.id/show_post/5...98b456c/1629/-
# ...

# %%
pattern = r"Quote:\nOriginal Posted By \S+"
len(re.findall(pattern, s)), re.findall(pattern, s)
# Out:
# (0, [])

# %%
pattern = r"Quote:\nOriginal Posted By \S+"
s = re.compile(pattern).sub("",s)
len(re.findall(pattern, s)), re.findall(pattern, s)
# Out:
# (0, [])

# %%
pattern = r"Quote:\nOriginal Posted By \S+"
s = re.compile(pattern).sub("",s)
len(re.findall(pattern, s)), re.findall(pattern, s)

# %%
re.search(pattern,s)
# Out:
# <_sre.SRE_Match object; span=(5656, 5660), match=' : 1'>

# %%
pattern = r"\s+:\s+\d{1}"
re.findall(pattern,s)
# Out:
# [' : 1',
#  ' : 1',
#  ' : 8',
#  ' : 8',
#  ' : 2',
#  ' : 2',
#  ' : 3',
#  ' : 3',
#  ' : 1',
#  ' : 1',
#  ' : 2',
#  ' : 2',
#  ' : 3',
#  ' : 3',
#  ' : 1',
#  ' : 2',
#  ' : 2',
#  ' : 3',
#  ' : 3',
#  ' : 1',
#  ' : 2',
#  ' : 2',
#  ' : 3',
#  ' : 3',
#  ' : 1',
#  ' : 2',
#  ' : 2',
#  ' : 3',
#  ' : 3',
#  ' : 1',
#  ' : 6',
#  ' : 7',
#  ' : 8',
#  ' : 8',
#  ' : 7',
#  ' : 8',
#  ' : 9',
#  ' : 6',
#  ' : 7',
#  ' : 8',
#  ' : 8',
#  ' : 7',
#  ' : 8',
#  ' : 9',
#  ' : 2',
#  ' : 2',
#  ' : 3',
#  ' : 3',
#  ' : 1',
#  ' : 7',
#  ' : 8',
#  ' : 7',
#  ' : 8',
#  ' : 9',
#  ' : 1',
#  ' : 1',
#  ' : 2',
#  ' : 2',
#  ' : 3',
#  ' : 3',
#  ' : 1',
#  ' : 2',
#  ' : 2',
#  ' : 3',
#  ' : 3',
#  ' : 1',
#  ' : 7',
#  ' : 8',
#  ' : 7',
#  ' : 8',
#  ' : 9',
#  ' : 2',
#  ' : 2',
#  ' : 6',
#  ' : 2',
#  ' : 6',
#  ' : 7',
#  ' : 7',
#  ' : 8',
#  ' : 7',
#  ' : 9',
#  ' : 7',
#  ' : 7',
#  ' : 8',
#  ' : 7',
#  ' : 9',
#  ' : 7',
#  ' : 7',
#  ' : 8',
#  ' : 7',
# ...

# %%
print('\U0001f681')
# Out:
# 🚁

# %%
import sys
sys.stdout.buffer.write(data.encode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e8c24f07c60d> in <module>()
#       1 import sys
# ----> 2 sys.stdout.buffer.write(data.encode('utf-8'))
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
with open('kaskus_tematik_prep.txt', 'wt', encoding='utf-8') as f:
    f.write(s)
    f.close()
# Out:
# 4681359
