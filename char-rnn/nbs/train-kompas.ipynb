# %%
# !wget -O kompas_e.txt https://storage.googleapis.com/simpsons2morty/kompas_e.txt

# %%
# !python train.py kompas_e.txt \
--model gru \
--n_epochs 40000 \
--print_every 500 \
--hidden_size 768 \
--n_layers 3 \
--learning_rate 0.001 \
--chunk_len 150 \
--batch_size 512 \
--cuda
# Out:
# Using CUDA
# Training for 40000 epochs...
#   1%|▍                                   | 499/40000 [13:44<18:07:17,  1.65s/it] 45s (500 1%) 1.4095]
# Whak: Tgb u inI RIMA SUCAPAYA ULAKI TERSEKPAR HANGAD MELUM ANAK KINI JOKOKDO   KARO
# Comment by Hakardi
#
#   2%|▉                                   | 999/40000 [27:21<17:48:15,  1.64s/it] 23s (1000 2%) 1.2451]
# Wh negara Rezeki melanggar pria negara, tembak itu hanyalah
#
# 	Reply by LV Zoo: lewajah guys Donald Ada
#
#   4%|█▎                                 | 1499/40000 [40:59<17:32:42,  1.64s/it] 0s (1500 3%) 1.0984]
# Wherlanca Bastian: kalo udah kaya media karena otak pemukiman  kita jg jgn d brikan tpi gak stres mute
#
#   5%|█▋                                 | 1999/40000 [54:36<17:18:08,  1.64s/it] 38s (2000 5%) 0.9594]
# Wha..Jakarta..salam 2 periode pak jokowi
# Comment by Sumartiyono Aji: Yang dislike Grobosorrrr gila!!
# C
#
# ...

# %%
model = 'kompas_e'
# !python generate.py '{model}.pt' \
--prime_str "fr ane"  \
--predict_len 200000  \
--temperature 0.8 \
--cuda >> '{model}_pred.txt'
# !cat '{model}_pred.txt'
# Out:
# /home/andri/char-rnn/char-rnn.pytorch/model.py:25: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().
#   output, hidden = self.rnn(encoded.view(1, batch_size, -1), hidden)
# fr anek direksi malah buzzer politik
# Comment by Khoer Adytianto: Bisa buat logika kalo saya lihat. yang slah bertele tele nuh.
#
#
# #ompone Saktiani: masyaalloh.apa kah gw..
# Comment by Adi Suryanto: Ada yg takut terlihat . liat prabowo juga g ada pembakaran hutan pun ttp anak jenius yg kata si wowo najis banget liatnya juga
#
# Comment by Setyawati Ahmad: Kasian ibuknya buat yg bermanfaat ajaa yg keras kepala, pk ganjar umur sudah pembuat fitnah doang yg dia bner dijlnkn dgn isis ..Lita2 motivasi nya jd pertanyaan bagi seluruh keluarga korban yang menghujat karena perbuatan Ibu adil dan juga Karena beliau.
# ...
