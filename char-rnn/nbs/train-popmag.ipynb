# %%
# !python train.py pop_mag.txt \
--model gru \
--n_epochs 7000 \
--print_every 50 \
--hidden_size 768 \
--n_layers 3 \
--learning_rate 0.001 \
--chunk_len 150 \
--batch_size 512 \
--cuda
# Out:
# Using CUDA
# Training for 7000 epochs...
#   1%|▎                                      | 49/7000 [01:21<3:11:45,  1.66s/it] 22s (50 0%) 1.9861]
# Whoya angus yg dito sussha
#
# Comment by Lu theh by maman fiw: Makta bisa ada kokpawan keriba...
# Commen
#
#   1%|▌                                      | 99/7000 [02:43<3:10:08,  1.65s/it] 45s (100 1%) 1.6615]
# Whan Bang Muluhhhha...
# Comment by Gaden Li: wow lawan balih bahan lus....cantikin ada nya bgn di crot
#
#   2%|▊                                     | 149/7000 [04:06<3:08:40,  1.65s/it] 7s (150 2%) 1.4982]
# Wha Maulana Kak.
# Comment by Beni Ramadhan: ada aja jadi pengen nya jadi ada paling nampan para mau bik
#
#   3%|█                                     | 199/7000 [05:28<3:07:16,  1.65s/it] 30s (200 2%) 1.3963]
# Whehell:  hehehe
#
# 	Reply by Popular Magazine Indonesia: Hihihihihi..sih...
# Comment by Agus Suryang Pra
#
# ...

# %%
# !python generate.py pop_mag.pt \
--prime_str "Comment by"  \
--predict_len 2000  \
--temperature 0.8 \
--cuda >> pop_mag_test.txt
# Out:
# /home/andri/torch/lib/python3.6/site-packages/torch/serialization.py:367: SourceChangeWarning: source code of class 'model.CharRNN' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
import string
len(string.printable)
# Out:
# 100

# %%
string.printable
