# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import string

# %%
cmt_thr = 20
auth_thr = 5
pred = True
f = open('pop_mag_pred.txt',encoding='utf-8').read()

lines = [l[11:] for l in f.split('\n') if 'Comment by' in l 
         and len(l[l.find(':')+2:]) > cmt_thr
         and len(l[:l.find(':')]) > auth_thr]
authors = [l[:l.find(':')] for l in lines]
comments = [l[l.find(':')+2:] for l in lines]
dfp = pd.DataFrame(np.array([authors,comments,lines]).T, columns=['author','comment','line'])
dfp['true'] = 0 if pred else 1
dfp.shape
# Out:
# (2396, 4)

# %%
dfp.drop_duplicates(inplace=True)
dfp.shape
# Out:
# (2222, 4)

# %%
cmt_thr = 20
auth_thr = 4
pred = False
f = open('pop_mag_e.txt',encoding='utf-8').read()
print('string length before :',len(f))
f = ''.join([st for st in f if st in string.printable])
print('string length after :',len(f))

lines = [l[11:] for l in f.split('\n') if 'Comment by' in l 
         and len(l[l.find(':')+2:]) > cmt_thr
         and len(l[:l.find(':')]) > auth_thr]
authors = [l[:l.find(':')] for l in lines]
comments = [l[l.find(':')+2:] for l in lines]
dfy = pd.DataFrame(np.array([authors,comments,lines]).T, columns=['author','comment','line'])
dfy['true'] = 0 if pred else 1
dfy.shape
# Out:
# string length before : 1597226
# string length after : 1588680
# (12268, 4)

# %%
dfy.drop_duplicates(inplace=True)
dfy.shape
# Out:
# (11930, 4)

# %%
# shuffle true label and randomly sample 1:1 class composition
dfy_shuf = dfy.sample(n=dfp.shape[0], random_state=42)
df = dfp.append(dfy_shuf, ignore_index=True)
# shuffle combined df rows
df = df.sample(frac=1).reset_index(drop=True)
df.shape, dfp.shape
# Out:
# ((4444, 4), (2222, 4))

# %%
df.to_csv('pop_mag.csv')

# %%
df
# Out:
#                                 author  \
# 0                     Syaiful Ramadhan
# 1                         Rafli Azhari
# 2                      Gendut Rindaman
# 3                   wahid hidayatullah
# 4                         Jamal Fataya
# 5                       heluwa habibti
# 6                        Subandrio Rio
# 7                          BUCEK PUTRA
# 8                          Gisik Kidul
# 9                                CVTan
# 10                         Sam Firdaus
# 11                       Dwi wijayanto
# 12                           Ali Yusup
# 13                         dedi Hizkia
# 14                           Dono Etaf
# 15                    Alfadh zul fauzi
# 16                       Maniak Gamers
# 17                      Meilani Meimei
# 18                      DuroMatt Carok
# 19                     Hendrik Zulvies
# 20                           Yoto Yoto
# 21                         CITRA BAGUS
# 22    mas bertto vloq nya orang taiwan
# 23                         Ahmad Yusuf
# 24                            Mas Huda
# 25                             AKUN ML
# 26                            Deo Deco
# 27                       Fadil Fadilah
# 28                           Hari Gino
# 29                     Rahmat Riansyah
# ...                                ...
# 4414                  Hilmi Al Fahlevi
# 4415                             Re Va
# 4416                     Zulkiri Jumba
# 4417                     Bagas Gunawan
# 4418                           Fra Fmr
# 4419                   Yudhi Reviyanto
# 4420                    arif kurniawan
# 4421                       fajar utomo
# 4422                           NYMS TV
# 4423                            AZR TV
# 4424                          vhia har
# 4425                      SCORPION R S
# 4426                        Joni Bravo
# 4427                          ADE YOAN
# 4428                     Ariono Dhanis
# 4429                         Dian Ardy
# 4430                       agi beatsgi
# 4431                 Anak Garsel Empuh
# 4432                      Widodo Irdwi
# 4433              Fitriansyah Ramadhan
# 4434                  Dian Ferdiansyah
# 4435                       Gio Aplimon
# 4436                        Delon Oreo
# 4437                          whan sgj
# 4438                        Ivan Arman
# 4439                     bayu ramadhan
# 4440                       java island
# 4441                The BroothersHoods
# 4442                    Muhammad Jamil
# 4443                       damar saker
#
#                                                 comment  \
# 0                         Njayy behanya segitu doang ??
# 1          dia aja blum kawin trus pengalaman dari mana
# 2     Makin lama makin pendek aja durasinya, buat 10...
# 3                 Kak tipsnya buat gedein penisnya dong
# 4                                Gracenya kemana tong..
# 5                  bungkus kontol aj di owar" prett....
# 6                                Ga tahan ga punya duit
# 7     Nah yg ke 11...klau aq main ma kamu mbak sampa...
# 8                          buat para telur aja mah ....
# 9     Di somerset kagak cocok banget jd koki modus p...
# 10    Video yg uncensored masih jago main bukit kemb...
# 11    percuma juga klo sampe pake teknik kalau  lagi...
# 12             kalau yang masak farah quin asik kayanya
# 13                             Habis itu kentu kenalpot
# 14              balik badan tehh, sedap pisan.. wkwkwkw
# 15                 Aduh kakak Sassha carissha tuh nahh
# 16               Yg setuju rheina gantiin sacha like yo
# 17                  Pitri pitri kalo di video cakep jga
# 18    Wellcome Tania sama Irene dan semua hal layak ...
# 19                                mantaap kalo inemm...
# 20          hadeh....sdh bikin ngeces mba. wkwkwkwk....
# 21                          Pantat nya licin tt nya nig
# 22                               Bareng temend dunkk sa
# 23    Itu sasaha ga usah pakai baju sekalian.... Sus...
# 24                               mbak grace emang josss
# 25    Siapa yang kesini cuma pengen liat t*t*k?  Sep...
# 26        cewek ini gaya ajahhh, pada gak cantiikkkkk,
# 27    Bagi ngomong pembantu rumah dari indonesia kat...
# 28    yg baru kali ini cowo yg mau aahhhh,  gak kena...
# 29                  Bambu nya di buat untuk ngocok tu..
# ...                                                 ...
# 4414  ini jd serba salah , apalagi liatnya d commute...
# 4415          Inem udah berubah  udah belajar pake baju
# 4416  kacaunetu paling sexy dan beauty Shita destya ...
# 4417  enak tuh jd terangsang lah tong teng teng jiwa...
# 4418                    Kalo aku mah sex in kamu aja...
# 4419      di majalah tidak kelihatan cba dongs sm sasha
# 4420                             tatonya bikin dosa kan
# 4421  sudah kayak gituuuuu suka buat anak nya ya si ...
# 4422                             brp X sehari byasanya?
# 4423                         #ndaeksa yang lebih suurr
# 4424                        Bole aku minta no.wa nyanga
# 4425  ini beri serius untuk mengapa tu. Liwit full v...
# 4426                        Anjir ! Gw coli liat ginian
# 4427  Mantap Ka gak ganti Oching secantik dan bergairah
# 4428                             Itu susu apa duren ya.
# 4429              Ini sekali goyang pondasi bisa roboh
# 4430  Ini fix gak usah ganti ini inem yg pertama,ini...
# 4431                       lovely ms Irene n ms Popular
# 4432  the favorite color trending Google please sending
# 4433                   Posisi ade gak bisa dikondisikan
# 4434                 Kurang.  Harusnya pake BH aja.....
# 4435                     kami suka cyla uhh sexy banget
# 4436  Punya pembantu gini mah saya gaji 3 jt/bulan m...
# 4437            suara mu kesel dengan payudara besar om
# 4438                    fake taik aja dengan nikmat nya
# 4439             Please kembalikan inem @GraceIskandar
# 4440     ayoo dycal matanya dijaga.. nsti echa jealous
# 4441  wes rasah nang kamar mandi lak karo koe, nang ...
# 4442  Bertobatlah engkau para wanita kurung tangan b...
# 4443  subscribe nya pasti banyak koleksi toge hot ny...
#
#                                                    line  true
# 0       Syaiful Ramadhan: Njayy behanya segitu doang ??     0
# 1     Rafli Azhari: dia aja blum kawin trus pengalam...     1
# 2     Gendut Rindaman: Makin lama makin pendek aja d...     0
# 3     wahid hidayatullah: Kak tipsnya buat gedein pe...     1
# 4                  Jamal Fataya: Gracenya kemana tong..     1
# 5     heluwa habibti: bungkus kontol aj di owar" pre...     1
# 6                 Subandrio Rio: Ga tahan ga punya duit     0
