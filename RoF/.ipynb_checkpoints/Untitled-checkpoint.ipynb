# %%
import sqlite3
from datetime import datetime, timedelta
def timenow(): return datetime.utcnow()
def dt2id(dt): return int((dt-datetime(2018,7,11)).total_seconds()*10000)
def id2dt(dtid): return datetime(2018,7,11)+timedelta(seconds=dtid/10000)
PATH = 'C:/Users/adsasmita/Desktop/RoF/RoF/' # local
cols = ['index','author','comment','line','truth']
DB_PATH = PATH+"db/"

# %%
dt = timenow()
dtid = dt2id(dt)
dataset = 'kompas'
line_index = 777
line = 'loooooooool'
correct = True
user_name = 'Anon'

# %%
# @app.route('/append_quiz', methods=['POST'])
# def append_quiz():
#     dt = timenow()
#     dtid = dt2id(dt)
#     conn = sqlite3.connect(DB_PATH+'Records.db')
#     d = conn.cursor()
#     rows = request.json['data']
#     for row in rows:
#         user_name, dataset, line_index, line, correct = \
#             row['user_name'], row['dataset'], row['index'], row['line'], row['correct']
#         d.execute('INSERT INTO Records (DTID, Datetime, UserName, Dataset, LineIndex, Line, Correct)'
#                   'VALUES (?,?,?,?,?,?,?)', (dtid, dt, user_name, dataset, line_index, line, correct))
#     conn.commit()
#     conn.close()
#     resp = {"append_status":True}
#     print(resp)
#     return jsonify(resp)

# %%
import sqlite3
conn = sqlite3.connect(DB_PATH+'Records.db')
c = conn.cursor()
# Create table
c.execute('''
CREATE TABLE Records (
    ID integer PRIMARY KEY AUTOINCREMENT NOT NULL,
    DTID integer,
    Datetime datetime,
    UserName text,
    Dataset text,
    LineIndex integer,
    Line text,
    Correct boolean
    )
''')
# # Insert a row of data
# c.execute('INSERT INTO Records (DTID, Datetime, UserName, Dataset, LineIndex, Line, Correct)'
#           'VALUES (?,?,?,?,?,?,?)', (dtid, dt, user_name, dataset, line_index, line, correct))
conn.commit()
conn.close()

# %%
import sqlite3
from datetime import datetime, timedelta
def timenow(): return datetime.utcnow()
def dt2id(dt): return int((dt-datetime(2018,7,11)).total_seconds()*10000)
def id2dt(dtid): return datetime(2018,7,11)+timedelta(seconds=dtid/10000)
PATH = 'C:/Users/adsasmita/Desktop/RoF/RoF/' # local
cols = ['index','author','comment','line','truth']
DB_PATH = PATH+"db/"
conn = sqlite3.connect(DB_PATH+'Records.db')
c = conn.cursor()
# Insert a row of data
# asdf = c.execute('PRAGMA table_info(Records)')
asdf = c.execute('SELECT * FROM Records')

# %%
asdf.fetchall()
# Out:
# [(1,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   3468,
#   'Luc[i]fer Gaming: Ada orang kayak gitu ya :)',
#   1),
#  (2,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   1585,
#   'Adam Mp: tdk tahan saya lihatNya',
#   1),
#  (3,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   451,
#   'bayu ramadhan: Inem @graceiskandar juara terhot',
#   1),
#  (4,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   716,
#   'Fauzan Azzima: Asisten rumah tangga gw kaya gini, gw entot tiap hari dah',
#   1),
#  (5,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   3399,
#   'luthan m akmal: #kamisukapopularmagazine wkwkwkwkwkw',
#   0),
#  (6,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   617,
#   'Abbom 11: liat sassha pagi pagi jadi seger dan si otong gua langsung bangun ',
#   0),
#  (7,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   3263,
#   'Budi Utama: Ga kebayang rasa nya si otong di jepit nenen nya',
#   0),
#  (8,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   2225,
#   'adis koeher: bahas International champions semua ',
#   1),
#  (9,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   1749,
#   'said hambrani: gua cari pembantu nih',
#   0),
#  (10,
#   376903888,
#   '2018-07-11 10:28:10.388811',
#   'Anon',
#   'pop_mag',
#   585,
#   'Qeis Mohammed: puting warnanya macem-macem? ada yang ijo gak?',
#   1),
#  (11,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   3468,
#   'Luc[i]fer Gaming: Ada orang kayak gitu ya :)',
#   1),
#  (12,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   1585,
#   'Adam Mp: tdk tahan saya lihatNya',
#   1),
#  (13,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   451,
#   'bayu ramadhan: Inem @graceiskandar juara terhot',
#   1),
#  (14,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   716,
#   'Fauzan Azzima: Asisten rumah tangga gw kaya gini, gw entot tiap hari dah',
#   1),
#  (15,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   3399,
#   'luthan m akmal: #kamisukapopularmagazine wkwkwkwkwkw',
#   0),
#  (16,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   617,
#   'Abbom 11: liat sassha pagi pagi jadi seger dan si otong gua langsung bangun ',
#   0),
#  (17,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   3263,
#   'Budi Utama: Ga kebayang rasa nya si otong di jepit nenen nya',
#   0),
#  (18,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   2225,
#   'adis koeher: bahas International champions semua ',
#   1),
#  (19,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   1749,
#   'said hambrani: gua cari pembantu nih',
#   0),
#  (20,
#   376918109,
#   '2018-07-11 10:28:11.810917',
#   'Anon',
#   'pop_mag',
#   585,
#   'Qeis Mohammed: puting warnanya macem-macem? ada yang ijo gak?',
#   1),
#  (21,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   3468,
#   'Luc[i]fer Gaming: Ada orang kayak gitu ya :)',
#   1),
#  (22,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   1585,
#   'Adam Mp: tdk tahan saya lihatNya',
#   1),
#  (23,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   451,
#   'bayu ramadhan: Inem @graceiskandar juara terhot',
#   1),
#  (24,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   716,
#   'Fauzan Azzima: Asisten rumah tangga gw kaya gini, gw entot tiap hari dah',
#   1),
#  (25,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   3399,
#   'luthan m akmal: #kamisukapopularmagazine wkwkwkwkwkw',
#   0),
#  (26,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   617,
#   'Abbom 11: liat sassha pagi pagi jadi seger dan si otong gua langsung bangun ',
#   0),
#  (27,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   3263,
#   'Budi Utama: Ga kebayang rasa nya si otong di jepit nenen nya',
#   0),
#  (28,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   2225,
#   'adis koeher: bahas International champions semua ',
#   1),
#  (29,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   1749,
#   'said hambrani: gua cari pembantu nih',
#   0),
#  (30,
#   376931933,
#   '2018-07-11 10:28:13.193392',
#   'Anon',
#   'pop_mag',
#   585,
#   'Qeis Mohammed: puting warnanya macem-macem? ada yang ijo gak?',
#   1),
#  (31,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   3468,
#   'Luc[i]fer Gaming: Ada orang kayak gitu ya :)',
#   1),
#  (32,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   1585,
#   'Adam Mp: tdk tahan saya lihatNya',
#   1),
#  (33,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   451,
#   'bayu ramadhan: Inem @graceiskandar juara terhot',
#   1),
#  (34,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   716,
#   'Fauzan Azzima: Asisten rumah tangga gw kaya gini, gw entot tiap hari dah',
#   1),
#  (35,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   3399,
#   'luthan m akmal: #kamisukapopularmagazine wkwkwkwkwkw',
#   0),
#  (36,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   617,
#   'Abbom 11: liat sassha pagi pagi jadi seger dan si otong gua langsung bangun ',
#   0),
#  (37,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   3263,
#   'Budi Utama: Ga kebayang rasa nya si otong di jepit nenen nya',
#   0),
#  (38,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   2225,
#   'adis koeher: bahas International champions semua ',
#   1),
#  (39,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   1749,
#   'said hambrani: gua cari pembantu nih',
#   0),
#  (40,
#   376945116,
#   '2018-07-11 10:28:14.511641',
#   'Anon',
#   'pop_mag',
#   585,
#   'Qeis Mohammed: puting warnanya macem-macem? ada yang ijo gak?',
#   1),
#  (41,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   3318,
#   'Aguz Rahayu: Anjirrr otngku berontak kamu ',
#   1),
#  (42,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   2640,
#   'cuy cis: Pasti putingya merah bngtzz',
#   0),
#  (43,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   2583,
#   'Mike Cool: Ganti Ochi Selena pasti mantaapp sekalian calon Inem',
#   1),
#  (44,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   250,
#   'DESTA CHANEL: klw gw di posisi om yayan pasti salfok itu njirr,,,wkwkwk',
#   1),
#  (45,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   2622,
#   'Dion Octovan: kok gw salfok ke pipinya hhh',
#   0),
#  (46,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   2176,
#   'Mister Insomnia: dyclan juara anjer wkwkwkkw lanjutkan bro',
#   1),
#  (47,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   787,
#   'S P: cuma dikasi tau 1 wtf',
#   1),
#  (48,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   2196,
#   'Farid Ryco: Kalau berani bugil aja ngak pakek handuk dan celana dalam',
#   0),
#  (49,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   1335,
#   'hery hore: ISDA hebat bela diri juga ternyata gk kalah sm diana putri & grace iskandar harusnya di gabungin tuh tiga2 nya',
#   1),
#  (50,
#   387722639,
#   '2018-07-11 10:46:12.263962',
#   'Anon',
#   'pop_mag',
#   3407,
#   'Jodie Tenrile: FTS Irzablessuet belakang moen rosi telp ayo juga ',
#   1),
#  (51,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   1870,
#   'Andi Cia: bnyakin vidio silsilia chan dong',
#   1),
#  (52,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   2608,
#   'Zain Elquds: B A B nya kok gak di shot?',
#   0),
#  (53,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   3729,
#   'Tubagus Laksono: Bagus banget mass lagunya bikin SEGERR!!!!!!',
#   0),
#  (54,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   993,
#   'Alex Docarmo: Gw pengen tips mlm jumat ma,kk sassha aja deh,bolehkn',
#   0),
#  (55,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   2567,
#   'Alan Ramadoni: kok popular makin ketutup yah pakaian renang? Gimana ya? Banyak cewe gak yaaaa',
#   1),
#  (56,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   595,
#   'ama zing: Btw yg ngevidio kalo dia cowok, ntab bgt deh',
#   0),
#  (57,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   451,
#   'bayu ramadhan: Inem @graceiskandar juara terhot',
#   1),
#  (58,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   2382,
#   'Yohanai Mahendra: Pasukan sabun mana suaranya....!!!!!!!',
#   1),
#  (59,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   2615,
#   'Aries Wildan: indah pemandangannya dan lubasi mulu.. semen susu mu aku mbak',
#   1),
#  (60,
#   387940308,
#   '2018-07-11 10:46:34.030862',
#   'Anon',
#   'pop_mag',
#   1642,
#   'bayu ramadhan: Yg cocok gantiin inem sasha carissa/pricyla neva apa balik grace iskandar lg ',
#   0),
#  (61,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   3759,
#   'Pll Fhcdffg: pricyla Neva cantik bikin sakit mata itu harus bersedang mis vidio nya',
#   1),
#  (62,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   2,
#   'Gendut Rindaman: Makin lama makin pendek aja durasinya, buat 10menitan min biar puas nontonnya',
#   1),
#  (63,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   1859,
#   'kelvin james: Ish situ gk malu bajunya gitu',
#   0),
#  (64,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   2967,
#   'brimob kontol: Bertobatlah engkau para wanita model sex sebelum km meninggal',
#   0),
#  (65,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   11,
#   'Dwi wijayanto: percuma juga klo sampe pake teknik kalau  lagi senam apa lagi , trs klo bsa bawain tentang kritik pembaangunan boleh',
#   1),
#  (66,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   374,
#   'Saiful Saad: Nenennya mantoppp lumayan niiii',
#   1),
#  (67,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   50,
#   'Satria Parnoga: Haduh susu viewer ramehed',
#   1),
#  (68,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   509,
#   'Yossy Plusitive: Booked? Number please? LoL',
#   0),
#  (69,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   3744,
#   'Vermont Kurniawan: Kami suka turboobs....',
#   1),
#  (70,
#   388099260,
#   '2018-07-11 10:46:49.926075',
#   'Anon',
#   'pop_mag',
#   3760,
#   'Tio Pebrianto: Kakak sassha galak dak nikah samong kah???',
#   1),
#  (71,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   595,
#   'ama zing: Btw yg ngevidio kalo dia cowok, ntab bgt deh',
#   0),
#  (72,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   2337,
#   'Ayu Widiyastuti: mirip kyk sibad hostnya',
#   0),
#  (73,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   4434,
#   'Dian Ferdiansyah: Kurang.  Harusnya pake BH aja.....',
#   1),
#  (74,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   2359,
#   'Zack Cloud: Sasha ganti aja si putih g string... belahanya dari belakang..',
#   1),
#  (75,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   1419,
#   'al abror: Kalau ada pembantu kek gini maulah aku.. 2x lipat pun gajinya gapapa.. serius ini.. dm aja ya',
#   0),
#  (76,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   884,
#   'sahabat CETTAR: ini baru lumayan seksi min...make orang tua nya mmmmmm',
#   1),
#  (77,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   2646,
#   'santiko fernandhez: I love u grace, eemuach',
#   0),
#  (78,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   2656,
#   'Tantan Pratama31: Waah sassha makin semok aja. Sering kimpoy ya ',
#   0),
#  (79,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   1159,
#   'Biji Peler: Thank popular megazine karena kalian saya bisa coli dengan nikmat nya',
#   0),
#  (80,
#   388468179,
#   '2018-07-11 10:47:26.817993',
#   'Anon',
#   'pop_mag',
#   1373,
#   'Sandrika Abdullah: Rasain luh berdua......  Bwat bahan colai w',
#   1)]

# %% [markdown]
# Test

# %%
import requests
import json
sample_json = json.loads(open('sample.json').read())
res = requests.post('http://localhost:5000/append_quiz', json=sample_json)
if res.ok:
    print(res.json())
# Out:
# {'append_status': True}
